# %%
#!/usr/bin/env python3
#_*_utf-8_*_
from datetime import datetime as dt
import matplotlib.pyplot as plt
import os
import glob
import time
import numpy as np
import scipy.stats as stats

all_files = glob.glob('Parsed*')

years = list(range(1970, 2017))

years.remove(2012)

times = {}

def get_sec(t):

    h, m, s = t.split(':')
    seconds = 3600*int(h)+60*int(m)+int(s)
    return seconds

#def get_sec(t):
#    h, m, s = t.split(':')
#    return int(h), int(m), int(s)

for y in years:
    
    f_open = open('ParsedNYC{}.txt'.format(y), 'r')
    
    times[y] = {'m':[], 'f':[], 'a':[], 'weather':[]}

    for r in f_open:
        row = r.split(',')
        try:
            h, m, s = row[-1].strip('\n').split(':')
            times[y]['a'].append(get_sec(row[-1].strip('\n')))
            if row[2] == 'M':
                times[y]['m'].append(get_sec(row[-1].strip('\n')))
            else:
                times[y]['f'].append(get_sec(row[-1].strip('\n')))
        except ValueError:
            continue

# %%
thirty_min = 30*60
time_ticks = np.linspace(7200, 34200, 100)
ticks_axes = np.arange(7200, 34200, thirty_min)
tick_lab = []
for t in ticks_axes:
    m, s = divmod(t, 60)
    h, m = divmod(m, 60)
    #print("%d:%02d:%02d" % (h, m, s))
    tick_lab.append("%d:%02d:%02d" % (h, m, s))

# %%
import datetime as dt
bins = np.linspace(7200, 34200, 100)
years = np.arange(1985, 1991)

# %%
file_d = glob.glob('*Dates.txt')
dates_file = open(file_d[0], 'r')
dates = []
for d in dates_file:
    d, m, y = d.split('-') 
    dates.append('-'.join([y.strip('\n'),m,d]))

# %%
# get weather data
file_w = glob.glob('*Weather.csv')
weather_data = []
weather_file = open(file_w[0], 'r')
for w in weather_file:
    w_row = w.split(',')
    w_row = [r.strip('"') for r in w_row]
    w_date = w_row[3]
    for d in dates:
        if d == w_date:
            weather_data.append(w_row)

# %%
# col headers
# Stations, Name, Date, AWND, PRCP (mm), TAVG (C), TMAX (C), TMIN, TOBS, TSUN, WDFG

# %%
distributions = {}
years = list(np.arange(1975, 2017))
#years = list(np.arange(2008, 2012))
years.remove(2012) # Hurricane Sandy
x_mult = 1
for y in years:
    distributions[y] = {'pdf':[], 'cdf':[], 'params':[]}
    for w in weather_data:
        yw, mw, sw = w[3].split('-')
        if str(y) == str(yw):
            try: 
                prt = [float(w[4]), float(w[5]), float(w[6]), float(w[7]), float(w[8])]
            except ValueError:
                prt = [float(e) if e != '' else float(-9999.9) for e in w[4:9]]
            times[y]['weather'].append(prt)
    try:
        # AWND PRCP TAVG TMAX TMIN WDFG
        # print the average temperature weather, for a day of the race.
        print('AWND'.ljust(7), 'PRCP (mm)'.ljust(10), 'TAVG (C)'.ljust(10), 'TMAX (C)'.ljust(10), 'TMIN (C)'.ljust(10))
        print('{:3.1f}'.format(prt[0]).ljust(10), 
              '{:3.1f}'.format(prt[1]).ljust(10), 
              '{:3.1f}'.format(prt[2]).ljust(10), 
              '{:3.1f}'.format(prt[3]).ljust(10), 
              '{:3.1f}'.format(prt[4]).ljust(10))
        
        data = times[y]['a']
        len_data = len(times[y]['a'])
        xmin, xmax = min(times[y]['a']), max(times[y]['a'])  
        lnspc = np.linspace(xmin, xmax, len_data)
        # fit a log-normal distribution
        ag, bg, cg = stats.lognorm.fit(data)

        # if fitting the log-normal fitting did not converge 
        pdf = stats.lognorm.pdf(lnspc, ag, bg, cg) 
        
        # retry the fit by specifying a parameter.
        if pdf[0] > 0.1:
            print('pdf did not converge, retrying with new parameter set')
            ag, bg, cg = stats.lognorm.fit(data, loc=0)
            pdf = stats.lognorm.pdf(lnspc, ag, bg, cg) 
        # create the pdf and cdf for the fitted log-normal distribution
        cdf = stats.lognorm.cdf(lnspc, ag, bg, cg)
        # save the distributions and parameters in a dictionary
        distributions[y]['cdf'].append(cdf)
        distributions[y]['pdf'].append(pdf)
        distributions[y]['params'].append([ag, bg, cg])
        print('year '+str(y)+' cdf: ', cdf[0])
        # plot the pdf to see how the PDF fits the data
        plt.plot(lnspc, pdf, label="log-normal")
        # plot the histogram of the data
        a, b, c = plt.hist(data, bins, alpha=0.5, label=str('all ')+str(y),
                              histtype='stepfilled', normed=True)
        #a1, b1, c1 = plt.hist(times[y]['m'], bins, alpha=0.5, label=str('males ')+str(y))
        #a2, b2, c2 = plt.hist(times[y]['f'], bins, alpha=0.5, label=str('females ')+str(y))
        
        # show important time breaks that people try and break
        # this the 4 hour break
        plt.axvline(4*3600, color='red', linewidth=1.5)
        # this is the three hour and thirty minute break
        plt.axvline(3*3600+30*60, color='red', linewidth=1.5)
        # this is the three hour break
        plt.axvline(3*3600, color='red', linewidth=1.5)
        mean_temp = np.mean(prt[3:5])
        x, y = np.min(b), np.max(a)
        plt.xlim(7200, 9*3600)
        plt.xticks(ticks_axes, tick_lab, rotation='vertical')
        plt.show()

    except KeyError:
        continue
#plt.legend(loc='upper right')
# Out:
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    22.2       14.4
# pdf did not converge, retrying with new parameter set
# year 1975 cdf:  0.00209457709974
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    5.1        -9999.9    12.2       7.8
# pdf did not converge, retrying with new parameter set
# year 1976 cdf:  0.000874349354324
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    13.9       4.4
# pdf did not converge, retrying with new parameter set
# year 1977 cdf:  0.0331539363633
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    21.1       11.7
# pdf did not converge, retrying with new parameter set
# year 1978 cdf:  0.0557745803735
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    21.7       14.4
# pdf did not converge, retrying with new parameter set
# year 1979 cdf:  0.00103167455858
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    10.6       6.7
# year 1980 cdf:  0.00165605300124
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    7.9        -9999.9    12.8       3.9
# pdf did not converge, retrying with new parameter set
# year 1981 cdf:  0.000635090286983
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    9.9        -9999.9    18.3       3.3
# year 1982 cdf:  0.00181678336348
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    17.2       11.1
# pdf did not converge, retrying with new parameter set
# year 1983 cdf:  0.000637279995299
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.5        3.0        -9999.9    23.9       17.2
# pdf did not converge, retrying with new parameter set
# year 1984 cdf:  0.000194849739102
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.5        0.0        -9999.9    20.0       11.1
# year 1985 cdf:  0.000458595617168
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.7        2.3        -9999.9    17.2       6.7
# year 1986 cdf:  0.000165393864405
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 2.5        0.0        -9999.9    15.6       5.0
# year 1987 cdf:  7.5094985117e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.4        0.0        -9999.9    17.8       11.1
# pdf did not converge, retrying with new parameter set
# year 1988 cdf:  3.22154395882e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.6        0.0        -9999.9    17.2       11.1
# year 1989 cdf:  1.41385437852e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.6        0.0        -9999.9    23.9       11.7
# year 1990 cdf:  8.41328065426e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.5        0.0        -9999.9    14.4       8.3
# year 1991 cdf:  2.18071731148e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.4        0.0        -9999.9    10.0       4.4
# year 1992 cdf:  2.83762976054e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.2        0.0        -9999.9    17.2       10.6
# year 1993 cdf:  4.48779718326e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.4        0.0        -9999.9    20.6       11.1
# year 1994 cdf:  2.24153226766e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 7.9        14.7       -9999.9    16.7       1.7
# year 1995 cdf:  1.10736599163e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.0        0.0        -9999.9    13.9       5.6
# year 1996 cdf:  1.8234514293e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.7        2.5        -9999.9    17.8       9.4
# year 1997 cdf:  9.0808625871e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.3        0.0        7.8        11.1       3.9
# year 1998 cdf:  2.51354337163e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 7.8        0.0        7.2        11.1       3.3
# year 1999 cdf:  1.11326012143e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 8.2        0.0        9.4        12.2       6.7
# year 2000 cdf:  2.19827846138e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.6        0.0        12.2       15.6       8.3
# year 2001 cdf:  7.46520960988e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.3        0.0        5.6        8.3        2.8
# pdf did not converge, retrying with new parameter set
# year 2002 cdf:  1.26110610105e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 2.5        0.0        16.1       18.3       13.3
# pdf did not converge, retrying with new parameter set
# year 2003 cdf:  2.85111848844e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.9        0.0        12.8       17.8       7.2
# year 2004 cdf:  0.00143489364212
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.5        0.3        -9999.9    18.3       8.3
# year 2005 cdf:  9.13989091748e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 2.2        0.0        -9999.9    9.4        0.6
# year 2006 cdf:  0.000101943477253
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.6        0.0        -9999.9    13.9       7.8
# year 2007 cdf:  0.00017798515864
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.6        0.0        -9999.9    10.0       3.9
# pdf did not converge, retrying with new parameter set
# year 2008 cdf:  0.000584877248404
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.6        0.3        -9999.9    15.0       9.4
# year 2009 cdf:  0.000491690775717
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.8        0.0        -9999.9    11.1       3.3
# pdf did not converge, retrying with new parameter set
# year 2010 cdf:  0.00117378964416
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 2.9        0.0        -9999.9    10.6       1.7
# year 2011 cdf:  0.00160155356567
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.5        0.0        10.9       13.3       3.3
# year 2013 cdf:  1.71474023283e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 11.7       0.0        7.2        10.0       5.0
# pdf did not converge, retrying with new parameter set
# year 2014 cdf:  3.63557349003e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.4        0.0        14.3       17.8       12.2
# year 2015 cdf:  3.5807146869e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 7.2        0.0        13.5       16.1       7.2
# year 2016 cdf:  2.06541318636e-05

# %%
through_time = []
#years = [2002]
# rework any distributions that still look weird
for y in years:
    temp = times[y]['weather'][0][-1]
        
    data = times[y]['a']
    len_data = len(times[y]['a'])
    xmin, xmax = min(times[y]['a']), max(times[y]['a'])
    
    lnspc = np.linspace(xmin, xmax, len_data)
        # fit a log-normal distribution
    ag, bg, cg = stats.lognorm.fit(data, loc=0)
    distributions[y]['params'] = []
    distributions[y]['params'].append([ag, bg, cg])
        # create the pdf and cdf for the fitted log-normal distribution
    pdf = stats.lognorm.pdf(lnspc, ag, bg, cg)
    cdf = stats.lognorm.cdf(lnspc, ag, bg, cg)
    distributions[y]['pdf'][0] = pdf
    distributions[y]['cdf'][0] = cdf
    #print(temp, y, distributions[y]['pdf'][0][0])
    print('#'*60)
    print('new pdf ', y, pdf[0], '  ', cdf[50])
    print('#'*60)
# Out:
# ############################################################
# new pdf  1975 1.15979527599e-05    0.931928048308
# ############################################################
# ############################################################
# new pdf  1976 1.56540552107e-05    0.943400294571
# ############################################################
# ############################################################
# new pdf  1977 0.000114633402787    0.824540863125
# ############################################################
# ############################################################
# new pdf  1978 0.000105516514128    0.650794327066
# ############################################################
# ############################################################
# new pdf  1979 5.07686019109e-05    0.664664402981
# ############################################################
# ############################################################
# new pdf  1980 5.2585393201e-05    0.687178663113
# ############################################################
# ############################################################
# new pdf  1981 3.46659567875e-05    0.64141154483
# ############################################################
# ############################################################
# new pdf  1982 6.15123626769e-05    0.592558721929
# ############################################################
# ############################################################
# new pdf  1983 1.7357571926e-06    0.000827182463117
# ############################################################
# ############################################################
# new pdf  1984 5.49167707461e-07    0.000227267510404
# ############################################################
# ############################################################
# new pdf  1985 1.07402523296e-06    0.000562656055124
# ############################################################
# ############################################################
# new pdf  1986 5.13851978838e-07    0.000205808197241
# ############################################################
# ############################################################
# new pdf  1987 2.9277228058e-07    8.32511611657e-05
# ############################################################
# ############################################################
# new pdf  1988 1.28800666795e-07    4.13252431943e-05
# ############################################################
# ############################################################
# new pdf  1989 6.11594027812e-08    1.47619155005e-05
# ############################################################
# ############################################################
# new pdf  1990 2.85338241585e-07    0.000102528174451
# ############################################################
# ############################################################
# new pdf  1991 9.90710030275e-08    2.78665791683e-05
# ############################################################
# ############################################################
# new pdf  1992 1.30189318788e-07    3.62257049466e-05
# ############################################################
# ############################################################
# new pdf  1993 1.45701669367e-07    5.32184453352e-05
# ############################################################
# ############################################################
# new pdf  1994 8.3542000509e-08    2.67168810829e-05
# ############################################################
# ############################################################
# new pdf  1995 4.88499274832e-08    1.39711759393e-05
# ############################################################
# ############################################################
# new pdf  1996 2.89297224823e-07    0.000122052023302
# ############################################################
# ############################################################
# new pdf  1997 3.81041607678e-08    1.1017733107e-05
# ############################################################
# ############################################################
# new pdf  1998 9.24068441342e-08    2.95961008264e-05
# ############################################################
# ############################################################
# new pdf  1999 4.60068718849e-08    1.33540436826e-05
# ############################################################
# ############################################################
# new pdf  2000 8.22463008379e-08    2.64532108945e-05
# ############################################################
# ############################################################
# new pdf  2001 1.77867713194e-07    7.51648148149e-05
# ############################################################
# ############################################################
# new pdf  2002 4.63137330149e-08    1.48312497346e-05
# ############################################################
# ############################################################
# new pdf  2003 8.26737725032e-08    3.192109426e-05
# ############################################################
# ############################################################
# new pdf  2004 8.79847652942e-08    3.46689699387e-05
# ############################################################
# ############################################################
# new pdf  2005 2.13058621814e-07    9.98917652099e-05
# ############################################################
# ############################################################
# new pdf  2006 3.09900484646e-07    0.00013297490632
# ############################################################
# ############################################################
# new pdf  2007 3.81277412462e-07    0.000190083590716
# ############################################################
# ############################################################
# new pdf  2008 9.8235748364e-07    0.000622213603526
# ############################################################
# ############################################################
# new pdf  2009 5.28997865154e-07    0.000262641313052
# ############################################################
# ############################################################
# new pdf  2010 1.52069753163e-06    0.00121224423934
# ############################################################
# ############################################################
# new pdf  2011 1.82990538692e-06    0.00165718561571
# ############################################################
# ############################################################
# new pdf  2013 1.31700273338e-07    4.87995308495e-05
# ############################################################
# ############################################################
# new pdf  2014 1.0490603541e-07    3.94017698762e-05
# ############################################################
# ############################################################
# new pdf  2015 1.6144088047e-07    6.44427639092e-05
# ############################################################
# ############################################################
# new pdf  2016 1.4111413247e-07    5.51370463359e-05
# ############################################################

# %%
# see how the new disitrbution fits
ty = 2002
time_lnspc = np.arange(2*3600, 9*3600)

data = times[ty]['a']
#cdf_test = distributions[ty]['cdf']
#pdf_test = distributions[ty]['pdf']

ag, bg, cg = distributions[y]['params'][0]

# create the pdf and cdf for the fitted log-normal distribution
pdf = stats.lognorm.pdf(lnspc, ag, bg, cg)
cdf = stats.lognorm.cdf(lnspc, ag, bg, cg)

plt.plot(lnspc, pdf, label="log-normal")
plt.xticks(ticks_axes, tick_lab, rotation='vertical')
plt.axvline(NYC_times[ty]['a'][20], color = 'red')
# plot the histogram of the data
a0, b0, c0 = plt.hist(data, bins, alpha=0.5, label=str('all ')+str(ty),
                      histtype='stepfilled', normed=True)
plt.title('year '+str(ty))
plt.show()

# %% [markdown]
# log normal goodness of fit tests.
#
# Assume a functional form relating the temperature to the mean and standard deviation of the distributions.

# %%
# Save the fitted distributions and time dictionaries
import pickle
pkl_cdfpdf = open('cdf_pdfNYC.pkl', 'wb')
pickle.dump(distributions, pkl_cdfpdf)
pkl_cdfpdf.close()

pkl_times = open('dict_timeNYC.pkl', 'wb')
pickle.dump(times, pkl_times)
pkl_times.close()

# %%
# load in saved distributions and time dictionaries
pkl_dist_file = open('cdf_pdfNYC.pkl', 'rb')
NYC_dist = pickle.load(pkl_dist_file)

NYC_time_files = open('dict_timeNYC.pkl', 'rb')
NYC_times = pickle.load(NYC_time_files)

# %%
20/50000
# Out:
# 0.0004

# %%
years = list(np.arange(1975, 2017))
#years = list(np.arange(2008, 2012))
years.remove(2012) # Hurricane Sandy
#years = [2003]
place_in_race = 20
percent = 0.0004
time_lnspc = np.arange(2*3600, 9*3600)
through_time_1 = []
through_time_n = []
time_1 = []
time_n = []

for y in years:
    data = sorted(NYC_times[y]['a'])
    place_in_race=int(percent*len(data))
    a, b, c = NYC_dist[y]['params'][0]
    full_dist = stats.lognorm.pdf(time_lnspc, a, b, c)
    full_cdf = stats.lognorm.cdf(time_lnspc, a, b, c)
    nth_place = data[place_in_race]
    delta = nth_place-7200
    
    Oneth = data[0]
    
    oneth_delta = Oneth-7200
    
    print('year', y, 'prob.', full_cdf[delta])
    
    time_1.append(Oneth)
    time_n.append(nth_place)
    
    time_convert = min(data)
    
    hr = time_convert/3600
    mn = 60*(hr-int(hr))
    sec = (mn - int(mn))*60
    print('top time: ', int(hr), int(mn), int(sec))
    through_time_1.append(full_cdf[oneth_delta])
    through_time_n.append(full_cdf[delta])

    # plot the histogram of the data
    plt.hist(data, bins, alpha=0.5, label=str('all ')+str(y),
             histtype='stepfilled', normed=True, color='green')
    plt.plot(time_lnspc, full_dist, color='blue')
    plt.axvline(data[place_in_race], color='red')
    plt.axvline(data[0], color='red')
    plt.xlim(2*3600, 9*3600)
    plt.ylabel(r'$Rarity$', fontsize=15)
    plt.xlabel(r'$Time$', fontsize=15)
    plt.xticks(ticks_axes, tick_lab, rotation='vertical')
    plt.show()
# Out:
# year 1975 prob. 0.00209457709974
# top time:  2 19 27
# year 1976 prob. 0.000874349354324
# top time:  2 10 8
# year 1977 prob. 0.0331539363633
# top time:  2 11 20
# year 1978 prob. 0.0557745803735
# top time:  2 12 11
# year 1979 prob. 0.00103167455858
# top time:  2 11 41
# year 1980 prob. 0.0016403621125
# top time:  2 9 40
# year 1981 prob. 0.000635090286983
# top time:  2 8 13
# year 1982 prob. 0.00181672294691
# top time:  2 9 28
# year 1983 prob. 0.000872901353099
# top time:  2 8 58
# year 1984 prob. 0.000249857562394
# top time:  2 14 53
# year 1985 prob. 0.00076233743136
# top time:  2 11 33
# year 1986 prob. 0.000278404926487
# top time:  2 11 6
# year 1987 prob. 7.99238425188e-05
# top time:  2 11 0
# year 1988 prob. 0.000122436309445
# top time:  2 8 19
# year 1989 prob. 1.87752128199e-05
# top time:  2 8 1
# year 1990 prob. 0.000187430769918
# top time:  2 12 39
# year 1991 prob. 0.000103887218031
# top time:  2 9 27
# year 1992 prob. 8.64477727295e-05
# top time:  2 9 28
# year 1993 prob. 0.000124331976793
# top time:  2 10 4
# year 1994 prob. 7.9022477063e-05
# top time:  2 8 36
# year 1995 prob. 1.2685078059e-05
# top time:  2 10 59
# year 1996 prob. 0.000271483497786
# top time:  2 9 54
# year 1997 prob. 9.21816684342e-05
# top time:  2 8 12
# year 1998 prob. 6.8222600067e-05
# top time:  2 8 45
# year 1999 prob. 4.03771338612e-05
# top time:  2 9 14
# year 2000 prob. 9.14379709551e-05
# top time:  2 10 8
# year 2001 prob. 0.000151068211301
# top time:  2 7 43
# year 2002 prob. 3.45730545866e-05
# top time:  2 8 6
# year 2003 prob. 0.000104929142491
# top time:  2 10 29
# year 2004 prob. 0.000121234966833
# top time:  2 9 27
# year 2005 prob. 0.000181861496126
# top time:  2 9 29
# year 2006 prob. 0.000419229867743
# top time:  2 9 58
# year 2007 prob. 0.000911792598602
# top time:  2 9 4
# year 2008 prob. 0.00174360796495
# top time:  2 8 43
# year 2009 prob. 0.000803815923903
# top time:  2 9 15
# year 2010 prob. 0.0029352461253
# top time:  2 8 14
# year 2011 prob. 0.00491335392975
# top time:  2 5 5
# year 2013 prob. 0.000405693923974
# top time:  2 7 51
# year 2014 prob. 0.000321094656428
# top time:  2 7 51
# year 2015 prob. 0.000447830445361
# top time:  2 10 33
# year 2016 prob. 0.000383420458878
# top time:  2 7 51

# %%
plt.semilogy(years, through_time_1, label='rarity of the winner') # rarity of winner
plt.semilogy(years, through_time_n, label='rarity of the last elite') # rarity of the last elite
plt.axvline(1983, color='red', linewidth=1.5)
#plt.axhline(3.5e-4, color='red', linewidth=1.5)
plt.legend(loc='upper right')
plt.savefig('rarity_through_time.png', dpi=1000)
plt.show()

# %%
fifteen_min = 15*60

time_min = 2*3600
time_max = 4*3600

time_ticksy = np.linspace(time_min, time_max, 100)
ticks_axesy = np.arange(time_min, time_max, fifteen_min)

tick_laby = []
for t in ticks_axesy:
    m, s = divmod(t, 60)
    h, m = divmod(m, 60)
    #print("%d:%02d:%02d" % (h, m, s))
    tick_laby.append("%d:%02d:%02d" % (h, m, s))

# %%
from matplotlib.font_manager import FontProperties

fig, ax1 = plt.subplots()
ax1.semilogy(years, through_time_1, label='rarity of the winner') # rarity of winner
ax1.semilogy(years, through_time_n, label='rarity of the last elite') # rarity of the last elite
ax1.set_xlabel(r'$Year$', fontsize=15)
ax1.set_ylabel(r'$Rarity$', fontsize=15)
ax1.set_ylim(1e-8, 1)

#plt.axvline(1987, color='red', linewidth=1.5)
#plt.axhline(3.5e-4, color='red', linewidth=1.5)
#plt.ylim(0.0001, 1)
ax2 = ax1.twinx()
ax2.plot(years, time_1, color='red', label='winning time')
ax2.plot(years, time_n, color='brown', label='last elite time')
ax2.set_ylim(time_min, time_max)
#ax2.set_yticks(ticks_axesy, tick_laby)
ax2.set_yticklabels(tick_laby)
ax2.set_ylabel(r'$Time$', rotation=270, fontsize=15, labelpad=15)
fig.tight_layout()

ax1.legend(loc=9, frameon=False, bbox_to_anchor=(0.25, -0.125))
ax2.legend(loc=9, frameon=False, bbox_to_anchor=(0.75, -0.125))
plt.savefig('NYCRarity_through_time2.png', dpi=1000, bbox_inches="tight")
plt.show()
