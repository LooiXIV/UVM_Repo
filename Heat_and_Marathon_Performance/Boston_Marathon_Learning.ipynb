# %%
#!/usr/bin/env python3
#_*_utf-8_*_
from scipy import stats  
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import scipy.stats as stats

all_files = glob.glob('Parsed*')

years = np.arange(1897, 2017)

times = {}

def get_sec(t):

    h, m, s = t.split(':')
    seconds = 3600*int(h)+60*int(m)+int(s)
    return seconds

for y in years:
    
    f_open = open('ParsedBoston{}.txt'.format(y), 'r')
    
    times[y] = {'m':[], 'f':[], 'a':[], 'weather':[]}

    for r in f_open:
        row = r.split(',')
        try:
            h, m, s = row[2].strip('\n').split(':')
            times[y]['a'].append(get_sec(row[2].strip('\n')))
            if row[1] == 'M':
                times[y]['m'].append(get_sec(row[2].strip('\n')))
            else:
                times[y]['f'].append(get_sec(row[2].strip('\n')))
        except ValueError:
            continue
    print(y, len(times[y]['a']))
# Out:
# 1897 10
# 1898 15
# 1899 11
# 1900 8
# 1901 9
# 1902 12
# 1903 10
# 1904 10
# 1905 10
# 1906 13
# 1907 10
# 1908 10
# 1909 20
# 1910 40
# 1911 25
# 1912 25
# 1913 35
# 1914 25
# 1915 34
# 1916 25
# 1917 18
# 1918 0
# 1919 0
# 1920 23
# 1921 32
# 1922 37
# 1923 33
# 1924 35
# 1925 36
# 1926 35
# 1927 35
# 1928 33
# 1929 41
# 1930 37
# 1931 40
# 1932 33
# 1933 44
# 1934 33
# 1935 60
# 1936 70
# 1937 61
# 1938 61
# 1939 66
# 1940 54
# 1941 29
# 1942 15
# 1943 35
# 1944 33
# 1945 33
# 1946 33
# 1947 41
# 1948 51
# 1949 51
# 1950 42
# 1951 52
# 1952 34
# 1953 35
# 1954 81
# 1955 35
# 1956 52
# 1957 25
# 1958 25
# 1959 25
# 1960 35
# 1961 102
# 1962 108
# 1963 125
# 1964 75
# 1965 100
# 1966 50
# 1967 50
# 1968 49
# 1969 91
# 1970 99
# 1971 101
# 1972 285
# 1973 160
# 1974 180
# 1975 1845
# 1976 1160
# 1977 2321
# 1978 4058
# 1979 5891
# 1980 3611
# 1981 5465
# 1982 5046
# 1983 5346
# 1984 5309
# 1985 3930
# 1986 3666
# 1987 5327
# 1988 5257
# 1989 5108
# 1990 7954
# 1991 7555
# 1992 8137
# 1993 7462
# 1994 8094
# 1995 8282
# 1996 35768
# 1997 8913
# 1998 10332
# 1999 11278
# 2000 15668
# 2001 13366
# 2002 14540
# 2003 17030
# 2004 16733
# 2005 3790
# 2006 19316
# 2007 20013
# 2008 21581
# 2009 22284
# 2010 22263
# 2011 23499
# 2012 21219
# 2013 15786
# 2014 31390
# 2015 26100
# 2016 25875

# %%
thirty_min = 30*60
time_ticks = np.linspace(7200, 34200, 100)
ticks_axes = np.arange(7200, 34200, thirty_min)
tick_lab = []
for t in ticks_axes:
    m, s = divmod(t, 60)
    h, m = divmod(m, 60)
    #print("%d:%02d:%02d" % (h, m, s))
    tick_lab.append("%d:%02d:%02d" % (h, m, s))
                    
import datetime as dt
bins = np.linspace(7200, 34200, 100)
years = np.arange(2010, 2017)

# %%
file_d = glob.glob('*Dates.txt')
dates_file = open(file_d[0], 'r')
dates = []
for d in dates_file:
    d, m, y = d.split('-') 
    dates.append('-'.join([y.strip('\n'),m,d]))

# %%
# get weather data
file_w = glob.glob('*Weather.csv')
weather_data = []
weather_file = open(file_w[0], 'r')
for w in weather_file:
    w_row = w.split(',')
    w_row = [r.strip('"') for r in w_row]
    w_date = w_row[3]
    for d in dates:
        if d == w_date:
            weather_data.append(w_row)

# %%
distributions = {}
years = list(range(1975, 2017))
years.remove(2012)
x_mult = 1
for y in years:
    distributions[y] = {'pdf':[], 'cdf':[], 'params':[]}
    for w in weather_data:
        yw, mw, sw = w[3].split('-')
        if str(y) == str(yw):
            try: 
                prt = [float(w[4]), float(w[5]), float(w[6]), float(w[7]), float(w[8])]
            except ValueError:
                prt = [float(e) if e != '' else float(-9999.9) for e in w[4:9]]
            times[y]['weather'].append(prt)
    try:
        # AWND PRCP TAVG TMAX TMIN WDFG
        # print the average temperature weather, for a day of the race.
        print('AWND'.ljust(7), 'PRCP (mm)'.ljust(10), 'TAVG (C)'.ljust(10), 'TMAX (C)'.ljust(10), 'TMIN (C)'.ljust(10))
        print('{:3.1f}'.format(prt[0]).ljust(10), 
              '{:3.1f}'.format(prt[1]).ljust(10), 
              '{:3.1f}'.format(prt[2]).ljust(10), 
              '{:3.1f}'.format(prt[3]).ljust(10), 
              '{:3.1f}'.format(prt[4]).ljust(10))
        
        data = times[y]['a'][20:-1]
        len_data = len(times[y]['a'])
        xmin, xmax = min(times[y]['a']), max(times[y]['a'])  
        lnspc = np.linspace(xmin, xmax, len_data)
        # fit a log-normal distribution
        ag, bg, cg = stats.lognorm.fit(data)

        # if fitting the log-normal fitting did not converge 
        pdf = stats.lognorm.pdf(lnspc, ag, bg, cg) 
        
        # retry the fit by specifying a parameter.
        if pdf[0] > 1:
            print('pdf did not converge, retrying with new parameter set')
            ag, bg, cg = stats.lognorm.fit(data, loc=0)
            pdf = stats.lognorm.pdf(lnspc, ag, bg, cg) 
        # create the pdf and cdf for the fitted log-normal distribution
        cdf = stats.lognorm.cdf(lnspc, ag, bg, cg)
        
        # save the distributions and parameters in a dictionary
        distributions[y]['cdf'].append(cdf)
        distributions[y]['pdf'].append(pdf)
        distributions[y]['params'].append([ag, bg, cg])
        print('year '+str(y)+' cdf: ', cdf[0])
        # plot the pdf to see how the PDF fits the data
        plt.plot(lnspc, pdf, label="log-normal")
        # plot the histogram of the data
        a, b, c = plt.hist(data, bins, alpha=0.5, label=str('all ')+str(y),
                              histtype='stepfilled', normed=True)
        #a1, b1, c1 = plt.hist(times[y]['m'], bins, alpha=0.5, label=str('males ')+str(y))
        #a2, b2, c2 = plt.hist(times[y]['f'], bins, alpha=0.5, label=str('females ')+str(y))
        
        # show important time breaks that people try and break
        # this the 4 hour break
        plt.axvline(4*3600, color='red', linewidth=1.5)
        # this is the three hour and thirty minute break
        plt.axvline(3*3600+30*60, color='red', linewidth=1.5)
        # this is the three hour break
        plt.axvline(3*3600, color='red', linewidth=1.5)
        mean_temp = np.mean(prt[3:5])
        x, y = np.min(b), np.max(a)
        plt.xlim(7200, 8*3600)
        plt.xlabel('Time', fontsize=12)
        plt.ylabel('Probability', fontsize=12)
        plt.xticks(ticks_axes, tick_lab, rotation='vertical')
        plt.savefig(str(y)+'_lognormBoston.png', dpi=1000, bbox_inches='tight')
        plt.show()

    except KeyError:
        continue
# Out:
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    11.1       2.8
# year 1975 cdf:  0.00245149327228
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    27.8       10.6
# pdf did not converge, retrying with new parameter set
# year 1976 cdf:  0.0014539362295
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    18.3       8.9
# pdf did not converge, retrying with new parameter set
# year 1977 cdf:  0.00166932962016
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.5        -9999.9    12.8       6.1
# year 1978 cdf:  0.000954859818447
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.3        -9999.9    7.2        4.4
# year 1979 cdf:  0.00168564263001
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    21.7       6.1
# year 1980 cdf:  2.03613607831e-07
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.3        -9999.9    11.7       3.3
# year 1981 cdf:  0.00137046488099
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    21.1       5.0
# year 1982 cdf:  0.000780904219889
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# -9999.9    0.0        -9999.9    11.7       3.9
# year 1983 cdf:  0.00253874302878
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.3        34.8       -9999.9    8.3        4.4
# year 1984 cdf:  0.00046549834127
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.1        0.0        -9999.9    21.7       7.8
# pdf did not converge, retrying with new parameter set
# year 1985 cdf:  0.000889777542798
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.5        3.8        -9999.9    18.3       7.8
# pdf did not converge, retrying with new parameter set
# year 1986 cdf:  0.000293653837126
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.6        0.8        -9999.9    10.0       7.8
# year 1987 cdf:  0.000169841568879
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.9        3.0        -9999.9    12.8       6.1
# pdf did not converge, retrying with new parameter set
# year 1988 cdf:  0.000292905848631
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.8        0.0        -9999.9    14.4       5.0
# pdf did not converge, retrying with new parameter set
# year 1989 cdf:  0.000462274117217
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.3        0.0        -9999.9    18.3       7.2
# year 1990 cdf:  0.00042022662384
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.3        0.0        -9999.9    18.3       7.2
# pdf did not converge, retrying with new parameter set
# year 1991 cdf:  0.000251522885974
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.2        0.0        -9999.9    17.8       5.6
# year 1992 cdf:  0.000351137569035
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 7.1        0.0        -9999.9    22.8       4.4
# year 1993 cdf:  0.0
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.2        0.0        -9999.9    13.9       5.6
# pdf did not converge, retrying with new parameter set
# year 1994 cdf:  0.000241630850799
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.6        0.0        -9999.9    10.6       1.1
# year 1995 cdf:  0.000431081956069
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.5        0.0        -9999.9    7.8        1.7
# year 1996 cdf:  8.18270090514e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.3        0.0        -9999.9    11.1       5.6
# year 1997 cdf:  0.000238124318669
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.0        16.8       10.0       12.2       7.2
# pdf did not converge, retrying with new parameter set
# year 1998 cdf:  2.08979828298e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.3        0.8        12.2       16.1       8.3
# year 1999 cdf:  4.12580221943e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.3        0.0        6.7        8.9        3.9
# year 2000 cdf:  6.02827487565e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.3        0.0        6.1        8.9        3.3
# year 2001 cdf:  2.76350305696e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.6        2.3        11.1       14.4       7.2
# year 2002 cdf:  4.29335114196e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.2        2.0        8.3        12.2       4.4
# year 2003 cdf:  6.82066902385e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.7        0.0        18.3       30.0       6.7
# year 2004 cdf:  9.77104815245e-05
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.5        0.0        15.0       18.9       10.6
# year 2005 cdf:  2.8670329295e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 4.7        0.3        -9999.9    11.7       6.1
# pdf did not converge, retrying with new parameter set
# year 2006 cdf:  2.07310944455e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 8.0        1.3        -9999.9    6.1        3.9
# pdf did not converge, retrying with new parameter set
# year 2007 cdf:  0.000318900063893
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 3.1        0.0        -9999.9    11.1       6.7
# pdf did not converge, retrying with new parameter set
# year 2008 cdf:  2.48181071315e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 6.2        2.3        -9999.9    8.9        3.3
# year 2009 cdf:  2.00010251104e-06
# AWND    PRCP (mm)  TAVG (C)   TMAX (C)   TMIN (C)
# 5.5        0.0        -9999.9    16.1       4.4
# pdf did not converge, retrying with new parameter set
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-251-90f0a09655f3> in <module>()
#      36         if pdf[0] > 1:
#      37             print('pdf did not converge, retrying with new parameter set')
# ---> 38             ag, bg, cg = stats.lognorm.fit(data, loc=0)
#      39             pdf = stats.lognorm.pdf(lnspc, ag, bg, cg)
#      40         # create the pdf and cdf for the fitted log-normal distribution
#
# /Users/Looi/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py in fit(self, data, *args, **kwds)
#    2192             raise TypeError("Unknown arguments: %s." % kwds)
#    2193
# -> 2194         vals = optimizer(func, x0, args=(ravel(data),), disp=0)
#    2195         if restore is not None:
#    2196             vals = restore(args, vals)
#
# /Users/Looi/anaconda/lib/python3.5/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     391             'initial_simplex': initial_simplex}
#     392
# --> 393     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     394     if full_output:
#     395         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# /Users/Looi/anaconda/lib/python3.5/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, **unknown_options)
#     536         if fxr < fsim[0]:
#     537             xe = (1 + rho * chi) * xbar - rho * chi * sim[-1]
# --> 538             fxe = func(xe)
#     539
#     540             if fxe < fxr:
#
# /Users/Looi/anaconda/lib/python3.5/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# /Users/Looi/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py in _penalized_nnlf(self, theta, x)
#    2011         x = asarray((x-loc) / scale)
#    2012         n_log_scale = len(x) * log(scale)
# -> 2013         return self._nnlf_and_penalty(x, args) + n_log_scale
#    2014
#    2015     # return starting point for fit (shape arguments + loc + scale)
#
# /Users/Looi/anaconda/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py in _nnlf_and_penalty(self, x, args)
#    1990     def _nnlf_and_penalty(self, x, args):
#    1991         cond0 = ~self._support_mask(x)
# -> 1992         n_bad = sum(cond0)
#    1993         if n_bad > 0:
#    1994             x = argsreduce(~cond0, x)[0]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save the newly fitted distribution values and parameters.

# %%
import pickle
pkl_cdfpdf = open('cdf_pdfBoston.pkl', 'wb')
pickle.dump(distributions, pkl_cdfpdf)
pkl_cdfpdf.close()

# %%
pkl_times = open('dict_timeBoston.pkl', 'wb')
pickle.dump(times, pkl_times)
pkl_times.close()

# %% [markdown]
# ## Load fitted distribution values and parameters.

# %%
import matplotlib.pyplot as plt
import pickle

# load in saved distributions and time dictionaries
pkl_dist_file = open('cdf_pdfBoston.pkl', 'rb')
Boston_dist = pickle.load(pkl_dist_file)

Boston_time_files = open('dict_timeBoston.pkl', 'rb')
Boston_times = pickle.load(Boston_time_files)

# %%
import scipy.stats as stats
import numpy as np
years = np.arange(2000, 2017)
# look at years and the temperature at race day
w_year = []
temp = []
dist_params = []
#a = []
#b = []
#c = []
mean = []
var = []
skew = []
kurt = []

for tw in years:
    try:
        temp.append(Boston_times[tw]['weather'][0][-2])
        w_year.append(tw)
        a = Boston_dist[tw]['params'][0][0]
        b = Boston_dist[tw]['params'][0][1]
        c = Boston_dist[tw]['params'][0][2]
        
        m, v, s, k = stats.lognorm.stats(a, b, c, moments='mvsk')
        
        mean.append(m)
        var.append(v)
        skew.append(s)
        kurt.append(k)
        
    except IndexError:
        pass

# %%
# make sure the distributions fit correctly
years = list(range(2000, 2017))
for tw in years:
    print(tw, stats.kstest(Boston_times[tw]['a'], 'lognorm', Boston_dist[tw]['params'][0])[-1])
    #print(tw)
# Out:
# 2000 0.000480552082817
# 2001 0.000565008502526
# 2002 0.0153483671961
# 2003 8.96023890605e-05
# 2004 2.77714776415e-05
# 2005 9.69714328672e-31
# 2006 5.12846445283e-16
# 2007 4.53502112576e-47
# 2008 3.06235643392e-15
# 2009 5.49805685384e-17
# 2010 8.2482409671e-22
# 2011 4.28083681983e-21
# 2012 1.68118878522e-17
# 2013 1.37307214648e-14
# 2014 6.5190477077e-15
# 2015 3.16621665054e-13
# 2016 1.21500423654e-19

# %%
# print the parameers to see if any look weird
print('year'.ljust(10), 'temp.'.ljust(10), 'mean'.rjust(10), 
      'variance'.rjust(15), 'skew'.rjust(10), 'kurtiosis'.rjust(10))
print('_'*75)
for y, t, m, v, s, k in zip(years, temp, mean, var, skew, kurt):
    print('{:4.0f}'.format(y).ljust(10), 
          '{:4.1f}'.format(t).ljust(10), 
          '{:10.3f}'.format(m.tolist()).rjust(10), 
          '{:13.3f}'.format(v.tolist()).rjust(15), 
          '{:10.3f}'.format(s.tolist()).rjust(10), 
          '{:10.3f}'.format(k.tolist()).rjust(10))
# Out:
# year       temp.            mean        variance       skew  kurtiosis
# ___________________________________________________________________________
# 2000        8.9        13580.210     4911602.286      0.809      1.186
# 2001        8.9        13967.095     5688853.365      0.743      0.999
# 2002       14.4        13854.905     5675050.857      0.735      0.975
# 2003       12.2        14651.526     6350939.960      0.737      0.981
# 2004       30.0        15824.961     7406360.928      0.421      0.317
# 2005       18.9        11669.051      711536.278      0.023      0.001
# 2006       11.7        13822.583     4738998.805      0.711      0.912
# 2007        6.1        14081.368     5126236.908      0.485      0.422
# 2008       11.1        13911.931     5233106.583      0.771      1.076
# 2009        8.9        13786.818     4898355.490      0.774      1.083
# 2010       16.1        13790.839     4956400.992      0.737      0.981
# 2011       16.1        13818.678     5120055.012      0.731      0.964
# 2012       30.6        13414.787     3806152.404      0.690      0.858
# 2013        9.4        12500.523     1934527.515      0.085      0.013
# 2014       20.6        14630.756    10048365.315      1.149      2.434
# 2015       10.6        13578.273     6044975.138      1.080      2.145
# 2016       19.4        14088.136     6089330.684      0.921      1.546

# %%
# check to see if temperature data is uniformally distributed using a rugplot.
#plt.hist(temp, alpha=0.5, histtype='stepfilled', color='yellow')
plt.plot(temp, [0.1]*len(temp), '|', color='green', mew=3, markersize=15)
plt.ylim(0.1, 0.11)
plt.show()
plt.close()

# %%
# filter marathons by temperature
tmin = min(temp)
tmax = max(temp)

# pools all race rests that have a particular race day temp.
temp2data = {}

print(len(temp))

num_seps = 6

years = list(np.arange(2000, 2017))
years.remove(2012)
# 2005 data is incomplete for some reason
years.remove(2005)

t_ran = np.linspace(tmin, tmax, num_seps)

for y in years:
    max_temp = Boston_times[y]['weather'][0][-2]
    
    y_data = Boston_times[y]['a']
    
    for n in np.arange(0, len(t_ran)-1):
        r_min, r_max = t_ran[n], t_ran[n+1]
        #print(r_min, r_max)
        key_min, key_max = '{:4.2f}'.format(r_min), '{:4.2f}'.format(r_max)
        if max_temp >= r_min and max_temp < r_max:
            
            #print(r_min, r_max)
            try:
                # concatenate lists if they fall in the same range
                temp2data['-'.join([key_min, key_max])] = temp2data['-'.join([key_min, key_max])]+y_data
            except KeyError:
                
                temp2data['-'.join([key_min, key_max])] = y_data
# Out:
# 17

# %%
sorted(list(set(temp2data.keys())))
# Out:
# ['11.00-15.90', '15.90-20.80', '25.70-30.60', '6.10-11.00']

# %%
# do pairwise t-test
import itertools 
mara_combos = list(itertools.combinations(set(temp2data.keys()), 2))
bins = np.linspace(7200, 34200, 100)
temp_ranges = ['6.10-11.00', '11.00-15.90', '15.90-20.80', '25.70-30.60']

temp2mean_pval = {}
temp2var_pval = {}
pval_numline = []
num_lin = []

fig, axes = plt.subplots(nrows=len(temp_ranges), ncols=len(temp_ranges), figsize=(15,15))
cn = 0


for col in temp_ranges:
    rn = 0
    for row in temp_ranges:
        
        if col == row:
            axes[rn, cn].set_xticks([])
            axes[rn, cn].set_yticks([])
        else:
            #num_lin.append(np.mean([float(e) for e in combos[0].split('-')]))

            # because data are log-normal distributed
            # transform the data.
            x1 = np.log(temp2data[col])
            x2 = np.log(temp2data[row])

            all_stats = stats.ttest_ind(x1, x2)
            var1 = np.var(x1)
            var2 = np.var(x2)

            #F_stat = stats.f_oneway(x1, x2)
            F_stat = var1/var2

            alpha = 0.05

            df1 = len(temp2data[col]) - 1
            df2 = len(temp2data[row]) - 1

            pF_val = stats.f.cdf(F_stat, df1, df2)
            #pF_val = stats.kruskal(x1, x2)

            y_max = 0.4

            #print(pF_val)
            # the normal 0.05 sig level seems to be too weak so lets go for a 5 sigma!

            #print(all_stats)
            axes[rn, cn].hist(temp2data[col], bins, alpha=0.5, 
                              normed = True, histtype='stepfilled', 
                              color='green')
            axes[rn, cn].hist(temp2data[row], bins, alpha=0.5, 
                              normed = True, histtype='stepfilled', 
                              color='blue')
            axes[rn, cn].set_xticks([])
            axes[rn, cn].set_yticks([])
            #axes[rn, cn].axis('off')
            #plt.title(combos)
            
            
            if all_stats[-1] < 3e-7:
                pval = 'p-value < 3e-7* \n '
            else:
                pval = 'p-value > 3e-7 \n '
            if pF_val < 3e-7:
                f_val = 'F-stat < 3e-7*'
            else:
                f_val = 'F-stat > 3e-7'
                
            stats_vals = pval + f_val
            #stats_vals = 'p-val: {0:.2e}\n'.format(pval)+'f-stat: {0:.2e}'.format(f_val)

            

            axes[rn, cn].set_ylim(0, 0.00025)
            axes[rn, cn].text(4*3600, 0.0002, stats_vals, fontsize=15)
        temp_labelx = r'{}$^\circ$ C'.format(col)
        temp_labely = r'{}$^\circ$ C'.format(row)
        if cn == 0:
            axes[rn, cn].set_ylabel(temp_labely, fontsize=15)
            
        if rn == 0:
            axes[rn, cn].set_title(temp_labelx, fontsize=15)

            #axes[rn, cn].text(25000, 0.00016, 'p-val: {0:.2e}'.format(all_stats[-1]))
            #axes[rn, cn].text(25000, 0.00013, 'f-stat: {0:.2e}'.format(pF_val))
            #plt.show()
        rn += 1
    cn += 1
plt.savefig('BostonPairWise.png', dpi=1000)
plt.tight_layout()
plt.show()
plt.close()

# %%
all_params = [mean, var, skew, kurt]

ylabs = ['mean', 'variance', 'skew', 'kurtoisis']

for labs, p in zip(ylabs, all_params):
    
    p_linreg = stats.linregress(temp, p)
    plt.plot(temp, p, 'o', color='blue')
    y = np.add(np.multiply(temp, p_linreg[0]), p_linreg[1])
    
    p_val = '{:4.3f}'.format(np.absolute(p_linreg[2]))
    p_val_y = max(p)*0.80
    p_val_x = max(temp)*0.75
    
    plt.text(p_val_x, p_val_y, 'p-value = '+p_val, fontsize=11)
    plt.plot(temp, y, color='red')
    plt.xlabel(r'Temperature $^{\circ}$C', fontsize=15)
    plt.ylabel(labs, fontsize=15)
    plt.savefig(labs+'vsTempBoston.png', dpi=1000, bbox_text='tight')
    plt.show()
    plt.close()

# %%
# save this data on mean, var, and skew to input into another jupyter notebook
Boston_ = open('BostonMVSK.pkl', 'wb')
MVSK = {}
for l, r in zip(ylabs, all_params):
    MVSK[l] = r
pickle.dump(MVSK, Boston_)    
Boston_.close()

# %%
# make a table of the ranges of mean variance and skew and kurtosis
print(' '.rjust(10), 'Min'.rjust(15), 'Max'.rjust(15), 'Mean'.rjust(15))
print('_'*60)
for l, r in zip(ylabs, all_params):
    print(l.rjust(10), 
          '{:10.3f}'.format(np.min(r)).rjust(15), 
          '{:15.3f}'.format(np.max(r)).rjust(15), 
          '{:15.3f}'.format(np.mean(r)).rjust(15))
# Out:
#                        Min             Max            Mean
# ____________________________________________________________
#       mean       11669.051       15824.961       13821.908
#   variance      711536.278    10048365.315     5220049.913
#       skew           0.023           1.149           0.682
#  kurtoisis           0.001           2.434           0.994
